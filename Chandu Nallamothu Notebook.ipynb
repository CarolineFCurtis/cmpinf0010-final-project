# %% [markdown]
# **First, I imported panda and the necessary visualization functions before I imported the data. I use these to analyze the amount of Fire Incidents per neighborhood in the City of Pittsburgh**

# %%
import pandas as pd
import geopandas
import matplotlib.pyplot as plt
# %matplotlib inline

data = pd.read_csv("Fire Incidents.csv", sep=",")
data
# Out:
#          call_no  incident_type                     type_description  \
# 0     F160029985          111.0                        Building fire
# 1     F180022058          111.0                        Building fire
# 2     F180022102          131.0               Passenger vehicle fire
# 3     F170043431          131.0               Passenger vehicle fire
# 4     F180021111          111.0                        Building fire
# ...          ...            ...                                  ...
# 9189  F230030699          162.0               Outside equipment fire
# 9190  F230030791          111.0                        Building fire
# 9191  F230031660          111.0                        Building fire
# 9192  F230031765          113.0  Cooking fire, confined to container
# 9193  F230031871          143.0                           Grass fire
#
#                                              address           alarm_time  \
# 0          800 BLOCK CENTER ST, WILKINSBURG PA 15221   2016-04-21 5:01:04
# 1           1100 BLOCK JANE ST, WILKINSBURG PA 15221   2018-03-13 8:34:43
# 2     SB STATE HWY 28 SB AT 31S, PITTSBURGH PA 15212  2018-03-13 11:54:23
# 3         1700 BLOCK BELLEAU DR, PITTSBURGH PA 15212   2017-05-31 8:39:47
# 4         2400 BLOCK VILLAGE RD, PITTSBURGH PA 15205  2018-03-09 10:26:42
# ...                                              ...                  ...
# 9189        4500 BLOCK LYTLE ST, PITTSBURGH PA 15207  2023-04-15 18:13:52
# 9190       200 BLOCK JUCUNDA ST, PITTSBURGH PA 15210  2023-04-15 23:11:30
# 9191           00 BLOCK LAWN ST, PITTSBURGH PA 15213   2023-04-19 1:03:28
# 9192     1400 BLOCK CRUCIBLE ST, PITTSBURGH PA 15220  2023-04-19 10:52:47
# 9193       3100 BLOCK WADLOW ST, PITTSBURGH PA 15212  2023-04-19 17:47:24
#
#       alarms primary_unit  census_tract        neighborhood  council_district  \
# 0          1      231EN16           NaN                 NaN               NaN
# 1          1      231EN16           NaN                 NaN               NaN
# 2          0      231EN32        2406.0                 NaN               NaN
# 3          0      231EN38        2509.0            Fineview               6.0
# 4          1      231EN31        2808.0           Fairywood               2.0
# ...      ...          ...           ...                 ...               ...
# 9189       0      231EN13        1501.0           Hazelwood               5.0
# 9190       1      231EN22        3001.0           Knoxville               3.0
# 9191       1      231EN10         409.0                 NaN               NaN
# 9192       1      231EN30        2814.0     Crafton Heights               2.0
# 9193       1      231EN35        2715.0  Marshall-Shadeland               1.0
#
#       ward         tract  public_works_division  pli_division  police_zone  \
# 0      NaN  4.200356e+10                    NaN           NaN          NaN
# 1      NaN  4.200356e+10                    NaN           NaN          NaN
# 2      NaN           NaN                    NaN           NaN          NaN
# 3     25.0  4.200325e+10                    1.0          25.0          1.0
# 4     28.0  4.200356e+10                    5.0          28.0          6.0
# ...    ...           ...                    ...           ...          ...
# 9189  15.0  4.200356e+10                    3.0          15.0          4.0
# 9190  30.0  4.200330e+10                    5.0          30.0          3.0
# 9191   NaN           NaN                    NaN           NaN          NaN
# 9192  28.0  4.200328e+10                    5.0          28.0          6.0
# 9193  27.0  4.200327e+10                    1.0          27.0          1.0
#
#      fire_zone   latitude  longitude
# 0         3-16  40.441275 -79.882485
# 1         3-21  40.436342 -79.881003
# 2         1-1A        NaN        NaN
# 3         1-10  40.460303 -80.006980
# 4         1-16  40.449009 -80.076607
# ...        ...        ...        ...
# 9189      2-13  40.413524 -79.948076
# 9190       4-6  40.417191 -79.991052
# 9191      2-10        NaN        NaN
# 9192      1-17  40.448579 -80.049711
# 9193      1-14  40.473552 -80.029849
#
# [9194 rows x 18 columns]

# %% [markdown]
# *As you can see from the data above there is quite a bit of information present in the csv file that is not useful to the specific data I am trying to analyze, so I filter this out.*

# %%
shortlist = data[['type_description', 'neighborhood']]
shortlist
# Out:
#                          type_description        neighborhood
# 0                           Building fire                 NaN
# 1                           Building fire                 NaN
# 2                  Passenger vehicle fire                 NaN
# 3                  Passenger vehicle fire            Fineview
# 4                           Building fire           Fairywood
# ...                                   ...                 ...
# 9189               Outside equipment fire           Hazelwood
# 9190                        Building fire           Knoxville
# 9191                        Building fire                 NaN
# 9192  Cooking fire, confined to container     Crafton Heights
# 9193                           Grass fire  Marshall-Shadeland
#
# [9194 rows x 2 columns]

# %% [markdown]
# *I filtered for the two most relevant columns: neighborhoods and types of fires*

# %%
MAQ = shortlist['neighborhood'].value_counts()
MAQ.plot.barh(subplots=True, figsize=(75,100), fontsize=60, color='orange')
plt.xlabel('Number of Fires', fontsize=80)
plt.ylabel('Location', fontsize=80)
plt.title('Number of fires in each neighborhood', fontsize=100)
# Out:
# Text(0.5, 1.0, 'Number of fires in each neighborhood')

# %% [markdown]
# *Since types of fires and neighborhoods are both categorical values it would be hard to represent them with graphs,so I had to count the number of fires for each neighborhood using a pandas count value function*

# %% [markdown]
# *After I did that I then made the bar graph using the data derived from the the count values function*

# %% [markdown]
# **Conclusion: Based on the data shown in my graph, the neighborhood of Carrick had the most amount of fires**
